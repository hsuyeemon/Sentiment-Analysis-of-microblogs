# %%
f = open('C:\\Users\\user\\Desktop\\nlp\\ark-tweet-nlp-0.3.2\\sentiment-analysis\\data\\input\\topic.2class.txt', 'r')
lines = f.readlines()
f.close()

# %%
arr= [];
for  i  in  range ( len(lines) ): 
    arr.append(lines[i].split('\t'))
print(len(arr))
# Out:
# 5416

# %%
#topics = set();
#for i in range(len(arr)):
    #topics.add(arr[i][1]);
    
#np
topic = np.empty((0,1), int)

# %%
topic_num=0;
splitList = [];
file = open('C:\\Users\\user\\Desktop\\nlp\\ark-tweet-nlp-0.3.2\\sentiment-analysis\\data\\output\\sameTopic.2class.txt',"w")   

i=0;
for topic in topics:
    list = [];
    file.write(arr[i][1]);
    file.write("\n");
    for i in range(len(arr)):
        if topic==arr[i][1]:
            list.append(arr[i]);
    splitList.append(list);
    file.write(str(list)); 
    file.write("\n");
#file.write(splitList) 
file.close()

# %%
splitList[0]
# Out:
# [['623166625550831620',
#   'zlatan',
#   'positive',
#   "Can't wait to see the @ChelseaFC blues and that dude Zlatan on Saturday. I mean @TooIaZy\n"],
#  ['623532967214907394',
#   'zlatan',
#   'positive',
#   "LOL Aulas still mad about the penalty Zlatan took a 2nd time a few month ago. I'm delighted by the fact that he is still butt-hurt about it!\n"],
#  ['623650255461056514',
#   'zlatan',
#   'positive',
#   "We are certainly gonna see Verratti in the 2nd half. I'm like a kid waiting for his present ;-) Oh &amp; Zlatan starts so thats great. #PSGFIO\n"],
#  ['623816868684558336',
#   'zlatan',
#   'positive',
#   'Zlatan to Milan may not be the best thing for both parties, He will be going to an un settled club, new coach (very tough personality) 1\n'],
#  ['624119953952739328',
#   'zlatan',
#   'positive',
#   '@Ibra_official Your record of moving to a new country and winning the league is 2nd to none! Man Utd need ZLATAN and ZLATAN needs the EPL..\n'],
# ...

# %%
import numpy as np
from sklearn.model_selection import KFold

folds = []
kf = KFold(n_splits=10)
#for train, test in kf.split(splitList[0]):
 #print("%s %s" % (train, test))
#for i in range(len(splitList)):
print(kf.get_n_splits(splitList));
for train_index, test_index in kf.split(splitList):
 #print("TRAIN:", train_index, "TEST:", test_index)
 print(type(train_index));
#kf.split(splitList[0])
# Out:
# 10
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
splitList[99]
# Out:
# [['641431504908873728',
#   'netflix',
#   'positive',
#   'I just want to sleep and watch Netflix until Friday for Bulldog Bash... Is that so much to ask for?\n'],
#  ['641432689308884992',
#   'netflix',
#   'positive',
#   '"@CurvedForever: I don\'t want a girl that parties all the time..gimme the one who\'s down to watch Netflix and order pizza on a Friday night"\n'],
#  ['641437197455896577',
#   'netflix',
#   'positive',
#   'Netflix and chill season coming you way! https://t.co/daKiB3kWex\n'],
#  ['641437943555620865',
#   'netflix',
#   'positive',
#   "Too hot. Too cold. Rain. Sun. Snow. Clear. People always have an excuse not to vote. Online you say? Nah, I'm watching Netflix.\n"],
#  ['641444044187504640',
#   'netflix',
#   'positive',
#   "@WoganHeidi the 5th quarter on Netflix is so good and sad, you should watch it if you haven't already!\n"],
#  ['641447792414621696',
#   'netflix',
#   'positive',
# ...

# %%
len(topics)
# Out:
# 100

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=10)
kf.get_n_splits(topics)
# Out:
# 10

# %%
kf.split(topics)
# Out:
# <generator object _BaseKFold.split at 0x000001DF5A2199A8>

# %%
#X = np.array(topics)
for train_index, test_index in kf.split(topics):
 print("TRAIN:", train_index, "TEST:", test_index)
# X_train, X_test = X[train_index], X[test_index]
 #y_train, y_test = y[train_index], y[test_index]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-d5a42459cd3f> in <module>()
#       1 #X = np.array(topics)
# ----> 2 for train_index, test_index in kf.split(topics):
#       3  print("TRAIN:", train_index, "TEST:", test_index)
#       4 # X_train, X_test = X[train_index], X[test_index]
#       5  #y_train, y_test = y[train_index], y[test_index]
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#     322         to an integer.
#     323         """
# --> 324         X, y, groups = indexable(X, y, groups)
#     325         n_samples = _num_samples(X)
#     326         if self.n_splits > n_samples:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     227         else:
#     228             result.append(np.array(X))
# --> 229     check_consistent_length(*result)
# ...

# %%
topics
# Out:
# {'@microsoft',
#  'ac/dc',
#  'amazon',
#  'amazon prime',
#  'amazon prime day',
#  'angela merkel',
#  'apple',
#  'apple watch',
#  'arsenal',
#  'barca',
#  'batman',
#  'bbc',
#  'bentley',
#  'bernie sanders',
#  'beyonce',
#  'bob marley',
#  'bobby jindal',
#  'chelsea',
#  'chris brown',
#  'conor mcgregor',
#  'david beckham',
#  'david cameron',
#  'digi',
#  'disneyland',
#  'donald trump',
#  'erdogan',
#  'eric church',
#  'federer',
#  'fleetwood mac',
#  'galaxy note',
#  'game of thrones',
#  'google',
#  'google+',
#  'grateful dead',
#  'hannibal',
#  'harper',
#  'harry potter',
#  'hillary',
#  'ibm',
#  'ihop',
#  'ios',
#  'ipad',
#  'iphone',
#  'ipod',
#  'jay-z',
#  'jeb bush',
#  'joe biden',
#  'jurassic park',
#  'jurassic world',
#  'justin',
#  'juventus',
#  'kerry',
#  'kurt cobain',
#  'labor day',
#  'lexus',
#  'madonna',
#  'magic mike xxl',
#  'mariah carey',
#  'messi',
#  'metlife',
#  'michael jackson',
#  'michelle obama',
#  'minecraft',
# ...
