# %%
print("please enter the original file name")
filename = input()
print(filename)
# Out:
# please enter the original file name
# topic.2class.txt
# topic.2class.txt

# %%
f = open('C://users//user//desktop//python//data//input//'+filename,"r")
lines = f.readlines()
f.close()

# %%
print(lines)
# Out:
# ['638061181823922176\tmichael jackson\tpositive\tJay Z joins Instagram with nostalgic tribute to Michael Jackson: Jay Z apparently joined Instagram on Saturday and.. http://t.co/Qj9I4eCvXy\n', "638125563790557184\tmichael jackson\tpositive\t18th anniv of Princess Diana's death. I still want to believe she is living on a private island away from the public. With Michael Jackson.\n", "638162155250954241\tmichael jackson\tpositive\t@etbowser do u enjoy his 2nd rate Michael Jackson bit? Honest ques. Like the can't feel face song but god it's so obvious they want MJ 2.0\n", '638180878594785280\tmichael jackson\tpositive\t@MariahCarey may he R.I.P. Happy Birthday Michael Jackson . :)\n', '638185679948660736\tmichael jackson\tpositive\tI just may be actually done with this award show.. Unless they get Michael Jackson on hologram.\n', '638201443044868096\tmichael jackson\tpositive\t@NICKIMINAJ today you try to destroy a Sir Mix-a-Lot hit - tomorrow Michael Jackson? WRITE YOUR OWN DAMN HOOKS!
# ...

# %%
arr= []
for  i  in  range ( len(lines) ): 
    arr.append(lines[i].split('\t'))
print(len(lines))
# Out:
# 5416

# %%
filename = filename[:-4]
file = open('C://users//user//desktop//python//data//output//tweets_'+filename+'.txt','w+') 
for  i  in  range (len(lines)): 
    #print(i)
    text = arr[i][3]
    file.write(text) 
file.close()
