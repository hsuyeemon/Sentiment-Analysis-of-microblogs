# %%
#relate with classes from original text file
f = open('C:\\Users\\user\\Desktop\\nlp\\ark-tweet-nlp-0.3.2\\sentiment-analysis\\data\\output\\extracted.2class.txt', 'r')
lines = f.readlines()
f.close()
arr= [];
print(len(lines))
for  i  in  range ( len(lines) ): 
    arr.append(lines[i].split('\t'))
    
arr
# Out:
# 3000
# [['positive',
#   'Jay Z joins Instagram nostalgic tribute Michael Jackson apparently joined Saturday\n'],
#  ['positive',
#   "anniv Princess Diana's death I still want believe she is living private island away public Michael Jackson\n"],
#  ['positive',
#   "do u enjoy 2nd rate Michael Jackson bit Honest ques can't feel face song god so obvious they want MJ\n"],
#  ['positive', 'may he R.I.P. Happy Birthday Michael Jackson :)\n'],
#  ['positive',
#   'I just may be actually done award show they get Michael Jackson hologram\n'],
#  ['positive',
#   'today you try destroy Sir hit tomorrow Michael Jackson WRITE OWN DAMN HOOKS\n'],
#  ['positive',
#   'VIRGO DAY- We wished fellow Virgo Captain Michael Jackson Happy Birthday 29th now time\n'],
#  ['positive',
#   "you may say oh it is August Liam Direction's birthday no also Michael Jackson\n"],
#  ['positive',
#   'Michael Jackson was man I remember watching Thriller Smooth Criminal music video 1st time it lit\n'],
#  ['positive',
#   "ALDUB RADIO MaAlden Monday NP I Just Can't Stop Loving You Michael Jackson This Spanish French versions #ALDUBTheREVELATION\n"],
#  ['positive',
#   '#NP Michael Jackson Human Nature #BrunchInTheCiti #tunein tracks Thriller album\n'],
#  ['positive',
#   "Happy 28th anniversary album generated #1's just katy's teenage dream a.k.a. Bad Michael Jackson\n"],
#  ['positive',
#   'Weeknd may be Michael Jackson reincarnated just saying are lot similarities musically #butthatsnoneofmybusiness\n'],
#  ['positive',
#   'Eric I heard love Michael Jackson got see him concert 4th row sweat hit me when he spun\n'],
#  ['positive',
#   'you got that website brothers mate school once said 2nd cousin was Michael Jackson similar tale this\n'],
#  ['positive',
#   'Very sad news Dr. Wayne Dyer passes away Ever Vanguard Michael Jackson May God grant him Peace\n'],
#  ['positive',
#   "#OnThisDay1987 CBS records shipped largest pre-order company's history Michael Jackson's album Bad\n"],
#  ['positive',
#   'I just texted friend be busy day tomorrow preparing roast Michael Jackson night Life is awesome\n'],
#  ['positive',
#   'mom I say birthday is me no you it mj michael jackson did he play ball too oh\n'],
#  ['positive',
#   'Jay Z pays tribute Michael Jackson he joins Instagram touching photo it may be last\n'],
#  ['positive', 'better dancer Michael Jackson mon spill beans\n'],
#  ['positive',
#   "1st record best memory buying album own $ was Michael Jackson's Thriller moment I rockstar\n"],
#  ['positive',
#   '#TodayInMusicHistory Michael Jackson earned 12th last solo lifetime song You Are\n'],
#  ['positive',
#   'Last Saturday would have been 58th birthday Mussic Michael Jackson coming just few minutes\n'],
#  ['positive',
#   'Let us dream tomorrow where we can truly love thsoul know ultimate truth heart creation Michael Jackson\n'],
#  ['positive',
#   's/o grade year when being michael jackson still lost bumblebee halloween costume contest\n'],
#  ['positive',
#   'Jay Z apparently joined Instagram Saturday posted photo montage himself Michael Jackson who would have been years old\n'],
#  ['positive',
#   'Remembering Michael Jackson Thursday September Starting Party king memory King\n'],
#  ['positive',
#   'Mojo just did mini-mix classic Michael Jackson that made Thursday better\n'],
#  ['positive',
#   'day September Michael Jackson was buried final resting place\n'],
#  ['positive',
#   '#Unbreakable will mark 1st time Janet Jackson has opened brother Michael\n'],
#  ['positive',
#   'Fandom Infiltration you may not know I accompanied mawm Michael Jackson Cirque\n'],
#  ['positive', 'may i remind you look Michael Jackson lol\n'],
#  ['positive',
#   'Michael Jackson place name Rare USA sold End Date Thursday Sep-10-201 #michaeljackson\n'],
#  ['positive',
#   "#FreddieMercury's Birthday Many you may have seen this rare pic him Michael Jackson\n"],
#  ['positive',
#   'everyone was so happy michael jackson came he sat started singing we gathered around listened\n'],
#  ['positive',
#   'Portland make sure catch Wednesday Alberta Rose Theater hoping least Michael Jackson covers\n'],
#  ['positive',
#   'follow Happy Sunday ET Extraterrestrial Storybook told Michael Jackson Movie Edit\n'],
#  ['positive', 'WALL MICHAEL JACKSON was no UK album charts September\n'],
#  ['positive',
#   'will be resuming Artist Week selections Tuesday featured artist time Michael Jackson\n'],
#  ['positive',
#   'Sunday brunch Bloody Mary is best Michael Jackson radio too #drinklocal #dolocal #music\n'],
#  ['positive',
#   'I get 1st slumber party Helen Byers Moore back day moments Michael Jackson\n'],
#  ['positive',
#   'September Michael Jackson made surprise appearance mtv vma where she danced Nsync\n'],
#  ['positive',
#   'showing Motown PBS Michael Jackson height fame Mind blowing moves #MoonwalkDebut\n'],
#  ['positive', 'omg London September going Michael Jackson kingvention day\n'],
#  ['positive',
#   'Rock Calendar Performing stage first time years Michael Jackson is reunited 30th Anniv Celeb\n'],
#  ['positive',
#   'when i was 4th grade sister convinced me michael jackson guy barney suit years\n'],
#  ['positive',
#   'favourite Michael Jackson is tingalingalingalingashingshongbhungbhaaanng tap moonwalk sun\n'],
#  ['positive',
#   'ICC i cud jst sing 1st time heard it Dumb I remember alotta highnotes sumthing michael jackson\n'],
#  ['positive',
#   "Monarchy expert D Michael Jackson will chat Queen Elizabeth's long reign tomorrow pm\n"],
#  ['positive',
#   'Barack Michelle Obama walk runway Style tonight tomorrow life will be complete That is\n'],
#  ['positive',
#   'Michelle Obama seems have really enjoyed theater going weekend She saw Kinky Boots Saturday King I Sunday\n'],
#  ['positive',
#   "Michelle Obama set bar exceptionally high What kind 1st lady would be WI wouldn't know never met her\n"],
#  ['positive',
#   'mom heard someone say Michelle Obama TV she started singing 5th Harmony Help\n'],
#  ['negative',
#   "Don't yall see what they doin distracting us today's kids will ever know July Barack Michelle obama got together\n"],
#  ['positive',
#   'Michelle Obama US 1st Lady teams Wale promote higher education\n'],
#  ['positive',
#   'Harvard educated First Lady Michelle Obama reminded attendees naturalization ceremony Wednesday\n'],
#  ['negative',
#   "best way find Malaysia Airlines Flight may be Michelle Obama's arms\n"],
#  ['negative',
#   'Many may not know Michelle Obama graduated Harvard What did she learn there She had surrender law license LYING\n'],
#  ['positive',
#   'First lady Michelle Obama gave passionate keynote address first White House Tribal Youth Gathering Washington Thursday\n'],
#  ['positive',
#   "Thomas Edison HS graduates will join 1st Lady Michelle Obama's Beating Odds Summit bringing together college bound\n"],
#  ['positive',
#   'Michelle Obama may be first lady shoes will make you streets freak bed\n'],
#  ['positive',
#   "Going First Lady Michelle Obama's Beating Odds Summit tomorrow #excited cameyyboo #WhiteHouse #USA\n"],
#  ['positive',
#   'MN college bound teens will be White House today 1st Lady Michelle Obama How they scored life changing invite\n'],
#  ['positive',
#   '#US 1st Lady Michelle Obama speaking Beating Odds Summit over college-bound students pentagon office\n'],
#  ['negative',
#   'Yesterday was National Hot Dog Day Michelle Obama called it Thursday\n'],
#  ['positive',
#   'Also first graduate college I agree Michelle Obama Making school cool is key success\n'],
#  ['positive',
#   'I admire Michelle Obama more Cant imagine how she survived being remote African village 1st time She deserved\n'],
#  ['positive',
#   'Is Michelle Obama sytycd crew dancing White House today I may have join\n'],
#  ['positive',
#   '1st Lady Michelle Obama was house What inspirational moment #ZenoFamily\n'],
#  ['positive',
#   'May I sent Children Nature Play sign First Lady Michelle Obama Today received thank you note\n'],
#  ['positive',
#   'Michelle Obama 1st gen college students education This should be cool thing do life\n'],
#  ['positive',
#   "Michelle Obama has dance Ellen DeGeneres celebrate 5th anniversary First Lady's\n"],
#  ['positive', 'No wonder you think Michelle Obama may be attractive\n'],
#  ['positive',
#   "Caller President Obama said-'If there was restriction me having 3rd term I would win it Was that precursor Michelle\n"],
#  ['negative',
#   "Study Michelle Obama's anti-obesity campaign may actually make people gain weight\n"],
#  ['positive', 'I just found today might get see Michelle Obama Friday\n'],
#  ['positive', 'i am going try meet Michelle Obama friday\n'],
#  ['positive',
#   'Happy 50th Birthday Michelle Obama winding Friday favorite FLOTUS quotes\n'],
#  ['negative',
#   'Kim Kardashian may have talent business woman Michelle Obama dont got She was just wife come\n'],
#  ['negative',
#   "Wouldn't surprise me Michelle Obama was brain child ISIS 1st place\n"],
#  ['positive',
#   "Michelle Obama Look Book 1st Lady dressed 4ever go taxpayer's $$$\n"],
#  ['positive',
#   'Laura W Bush Michelle Obama Psalm Long may he live receiving gold Arabia prayed cease\n'],
#  ['positive',
#   'Michelle Obama Barack Honor Colored Girls February last day black history mon\n'],
#  ['positive',
#   'Jan runs Michelle Obama way charity event Storm clouds begin brew women they battle psychic control\n'],
#  ['positive',
#   "Sum1'll say he saw PMB Michelle Obama hotel kissin nxt readn it online alrdy No e4ts find authenticity d story\n"],
#  ['positive',
#   'Ugh Michelle Obama was selected Best Dressed Woman Sunday Times Time\n'],
#  ['positive',
#   'First Lady Michelle Obama is elegant classy 1st who presence touch heart us #LoveMyPresident &FirstLady\n'],
#  ['positive',
#   'you may be right You also forgot Michelle Obama Rihanna cover granted interviews\n'],
#  ['positive',
#   "AMERICA friends are playing Jimmy Kimmel show tomorrow night Michelle Obama couldn't be more proud\n"],
#  ['negative',
#   'first time adult lifetime really proud country MOST UN-AMERICAN STATEMENT DISGRACED 1ST LADY MICHELLE OBAMA\n'],
#  ['negative',
#   'Plus Michelle Obama trying pick what foods we can eat I may have read that wrong\n'],
#  ['negative',
#   'Faux FLOTUS Michelle Obama recently floated Sheerly repugnant suggestion she may run POTUS\n'],
#  ['negative',
#   'How r Christian Right going accept this 1st lady when Flotus Michelle Obama got slammed bare arms\n'],
#  ['positive',
#   'Michelle Obama is most active 1st ladies Eleanor Roosevelt tbh\n'],
#  ['negative', 'put stripper White House RWNJs say Michelle Obama has class\n'],
#  ['positive',
#   'Kanye really did run president Michelle Obama would still be baddest 1st lady ever\n'],
#  ['negative',
#   'Michelle Obama jump race president 3rd term communist islamists WH NO\n'],
#  ['positive',
#   'I may have treat you guys tonight can play Minecraft me ;) #TheDream\n'],
#  ['positive',
#   'Looking forward learning Skype Minecraft Sway more Thurs/Fri TnT Still room #psd70\n'],
#  ['positive',
#   'Doing mock build Ashoka now I think might her Minecraft tomorrow so definitely stream it #disneyinfinity\n'],
#  ['positive',
#   'Had fun streaming friends Hopefully get back Minecraft tomorrow Goodnight\n'],
#  ['positive',
#   'Calling Minecraft fans Saturday August survival night Come show us building\n'],
#  ['positive',
#   "birthday is Sunday August I can't wait hope get ps4 Minecraft bo2 advanced warfare gta\n"],
#  ['positive', 'course mom can make Minecraft cake Happy 6th little man\n'],
#  ['positive',
#   'Early upload Minecraft week going be away computer essentially day tomorrow\n'],
#  ['positive',
#   'LIMITED AVAILABILITY REGISTER TODAY Minecraft may have started just game it has become much more\n'],
#  ['positive',
#   'y/o just back talked me Tomorrow school logging Minecraft destroying entire village\n'],
#  ['positive',
#   'Playing #Diversity2 Minecraft friends #playing #it #for #my #4th #time\n'],
#  ['positive',
#   '3rd grader tells me interested Minecraft lessons He would love show you ropes\n'],
#  ['positive',
#   'Gym time :) Friday stream will be back Minecraft See you then\n'],
#  ['positive', "Ruben Percy Porker Moo's Minecraft pet house pig :-D\n"],
#  ['positive', 'Next Thursday helping free Minecraft event Find more here\n'],
#  ['positive',
#   'Thank you coming stream tonight Very laid back :D Tomorrow We play Minecraft more\n'],
#  ['positive',
#   'Happy Saturday Petersfield just had excellent drop new books everything William Boyd Minecraft\n'],
#  ['positive',
#   "Reply tweet challenge you may have idea's want me do Minecraft I will make sure them\n"],
#  ['positive',
#   'WFS Saturday is start you have Minecraft up open viewers joining us\n'],
#  ['positive',
#   'I may get record Minecraft TheKindFox super happy :) HUGS <3 Did you manage check skype invites\n'],
#  ['positive',
#   'Sunday is full Minecraft hype Kickback Can you make Pick game\n'],
#  ['positive',
#   'I am now attending #insomnia55 Friday doing panel making games Minecraft Not sure will stay whole weekend yet\n'],
#  ['positive',
#   'Rugid_azz MaribolHD new followers Thanks coming hope you guys come back tomorrow Minecraft boys Lots fun\n'],
#  ['positive',
#   'Reserve spot next Party Camp Programming video creation Minecraft Starting Aug grades\n'],
#  ['positive',
#   "condition even she doesn't play Minecraft I don't mind may consider applying Senior\n"],
#  ['positive', 'August Free Kids Minecraft App Building Creating web apps\n'],
#  ['positive',
#   'not excited Minecraft game is coming #WiiU 3rd party support love see other TT games\n'],
#  ['positive', 'Okay sweet give it go when I hop Minecraft Sunday\n'],
#  ['positive',
#   'you are curious wild Friday nights I promised Liam would play Minecraft Kennedy requested burritos dinner\n'],
#  ['positive',
#   'May I use amazing Minecraft tracks beginning interview doing website seconds\n'],
#  ['positive',
#   'Parent/child modeling class MINECRAFT Saturday tomorrow pm Austin Tinkering School only\n'],
#  ['positive',
#   'Let me know games u want stream KZ Sf COD Ghosts AW I am Bread Minecraft Devil may cry DCUO Warframe #PlayStation\n'],
#  ['positive',
#   'Also tomorrow streaming actual Minecraft game be there Um make thing what playing\n'],
#  ['positive',
#   'Sorry video Minecraft yesterday It literally JUST UPLOADED will be monday i think you enjoy it :)\n'],
#  ['positive', 'I liked video Meet Medic Minecraft April Fools\n'],
#  ['positive',
#   'Stream coming tomorrow streaming Minecraft madden come check it\n'],
#  ['positive',
#   'Sorry stream last night I crashed will be tonight sure Then back Minecraft pc tomorrow\n'],
#  ['positive', 'stream tonight guys girls Minecraft will be tomorrow\n'],
#  ['positive',
#   'Thanks everyone coming chat today be back tomorrow midday Minecraft\n'],
#  ['positive',
#   'Guys Good news I found authentication URL Minecraft means may be getting it unblocked fingers crossed\n'],
#  ['positive', '4th graders are going build missions Minecraft #elemcode\n'],
#  ['positive',
#   'going play Minecraft tomorrow be survival plot user name is ssmississippi\n'],
#  ['positive',
#   'bed looking forward flumps playing Minecraft Martin Chloe tomorrow Hmmm minecraft flump #flumplover #minecraft\n'],
#  ['positive',
#   "Yesterday's Minecraft video is page when searching mods This good going me :P\n"],
#  ['positive',
#   'Minecraft account Derosion Retweeted may I wish best legend rank\n'],
#  ['positive',
#   "Anyway gonna make something Minecraft #TCMParty's 4th anniversary Hold stupid PS3 is updating Again\n"],
#  ['positive', '5th grade class study decimals Minecraft\n'],
#  ['positive',
#   'ok do workout kids are engrossed Minecraft videos Happy Friday\n'],
#  ['positive',
#   'Music Minecraft best thing free Friday is streaming OMG Get here\n'],
#  ['positive',
#   'plzz accept Minecraft update least Sunday Monday please we are waiting it have been\n'],
#  ['positive',
#   "Sorry lack Minecraft computer is broke I can't play it PC May try record Xbox get new\n"],
#  ['positive', 'Tomorrow i will play Minecraft friend\n'],
#  ['positive',
#   'you may have not won Mario Kart proved Minecraft is kingdom #BowDown #LoGLive\n'],
#  ['positive', 'I may have just bought Minecraft\n'],
#  ['positive', 'Good day vids tomorrow Stasis Long Dark Rebirth Minecraft\n'],
#  ['positive',
#   'Tomorrow be streaming Minecraft est See you there #minecraft #PS4 #Twitch\n'],
#  ['positive',
#   "Many thanks Minecraft It has enriched son's life May you find happiness fulfillment success future endeavours\n"],
#  ['positive',
#   'Hello I have idea next version Minecraft You may add dirty cobblestone stone brick etc\n'],
#  ['positive',
#   'you will watch Minecraft have Half-life Friday only game ready stream I am willing play\n'],
#  ['positive',
#   'Holy shit been playing Minecraft Alpha Nov That is actually crazy I do not want know how many hours logged\n'],
#  ['positive',
#   'Was taking so long find cat Minecraft jungle I may have set it fire little anger\n'],
#  ['positive',
#   'I need 3rd game record suggestions guys :) moment have Dawn Minecraft\n'],
#  ['positive',
#   'Guy I will be streaming live tomorrow starting little play Minecraft tweet what u want see world :)\n'],
#  ['positive',
#   'going be posting tutorial you asked me do weeks ago Minecraft Take look tomorrow sorry delay\n'],
#  ['positive',
#   "Well I dropped ball Got ps4 haven't made videos Minecraft Bloodborne Tomorrow post make it\n"],
#  ['positive',
#   'Longest stream while Will be streaming early tomorrow probably PST League Minecraft CS GO maybe xD\n'],
#  ['positive', 'work Minecraft appeases great May he rain catnip milk you\n'],
#  ['positive',
#   'So I am gonna be going Minecraft tournament SoPro games Overland Park Ks Saturday October :D gona rek nubes\n'],
#  ['positive',
#   'I liked video MHC Conversation TechnaScribe September Minecraft\n'],
#  ['negative',
#   "Mike I think you are large piece cow dung FDA may have approved GMO's sir must be bed Monsanto KOCH\n"],
#  ['negative',
#   'Rock legend Neil Young rightly attacking evil Monsanto So now banned BBC\n'],
#  ['negative',
#   'Monsanto Owns Government House Just Banned GMO Labeling Truthstream Media\n'],
#  ['negative',
#   'message is Monsanto Bring it You may have money we people always win\n'],
#  ['negative',
#   "Monsanto may be evil it controls seeds pesticides that doesn't mean GMO is bad\n"],
#  ['negative',
#   'This is not being shared you mainstream press it coming March Monsanto\n'],
#  ['negative',
#   "Stop Monsanto's Dream Bill Senate GMO's may be very dangerous\n"],
#  ['negative', 'Monsanto Hits Wrong Notes NationofChange\n'],
#  ['negative', "Don't look too hard you may find Monsanto responsible\n"],
#  ['negative', 'DEADline Aug Fight DARK Act Monsanto\n'],
#  ['negative',
#   "Many people planet have death wish They don't care Monsanto is killing them not Sometimes you may as well save breath\n"],
#  ['negative',
#   "Interesting #agriculture #IP news Monsanto's 1st genenration GMO crop patents are expiring US\n"],
#  ['negative', 'is that what you want grandkids #MAM march Monsanto\n'],
#  ['positive',
#   'It may be true Monsanto is terrible PR believe it not evil company #FeedThe9\n'],
#  ['negative',
#   "Dairy cows treated Monsanto's growth hormone may sharply increase cancer risk other diseases\n"],
#  ['negative', 'time this was banned along Monsanto itself\n'],
#  ['negative',
#   'conveyor belt goods bought Monsanto Supermarket shall we say assembly line puppets MON bathes\n'],
#  ['negative',
#   'Did it EVER occur anyone Monsanto may be executing honey bees poison ROUND CONTROL food supply limiting natural foods\n'],
#  ['negative',
#   'I work Monsanto not possible think myself talk Really Happy Saturday\n'],
#  ['negative',
#   'Monsanto wants merge Syngenta change name wash away bad reputation 3rd most disliked company\n'],
#  ['negative',
#   'move cigarette companies Monsanto special place sun #WhyIWouldMakeAGreatPresident\n'],
#  ['negative',
#   'March Monsanto movement shows we can kick butts market place control\n'],
#  ['negative',
#   'GMOs Food Labeling video source March Monsanto Consumers have right know going\n'],
#  ['negative', 'may states wake evil Monsanto is justice prevails\n'],
#  ['negative',
#   'too funny Monsanto begin spraying cities chemical designed make people not hate\n'],
#  ['negative',
#   'Lying bucket turds Clinton Foundation may have taken money Gates Monsanto\n'],
#  ['positive',
#   "Antonio do you have time talk Monday monsanto's new spray greenhouse show\n"],
#  ['negative', "That may be so us worry Hillary's love Wall Street Monsanto\n"],
#  ['negative',
#   "New studies Monsanto's lies #BanGMO #StopDarkAct #GrowOrganic #BanPesticides #BanGlyphosate #BanRoundup\n"],
#  ['negative',
#   'I would bet Monsanto factors this somehow Obvious they want control food supply even it may cause cancer\n'],
#  ['negative', 'Please explain why you support Monsanto\n'],
#  ['positive',
#   "snapshot Monsanto's share price S&P last months MON down almost weeks\n"],
#  ['negative',
#   'Why name Monsanto am I sitting home Saturday night trolling used RVs Craigslist oh yeah have date #FuckAllYall\n'],
#  ['negative',
#   'Should have first series videos critiquing protest March Monsanto tonight\n'],
#  ['positive',
#   "Monsanto's bln offer deserves hearing says Syngenta should talk show investors it has better plan $SYT $MON #mergers\n"],
#  ['positive', 'Monsanto may be buy Syngenta reported why important\n'],
#  ['negative',
#   'Shareholders upset SYN board Syngenta must explain Plan B Monsanto pulls deal investors say $SYT $MON\n'],
#  ['negative',
#   'Nick Meyer March Monsanto United States citizens battle legislation DARK Act HR\n'],
#  ['negative',
#   'Chemtrails poisonous Aluminum dim sun Monsanto unveils new patents GM seeds tolerant sunlight deprivation\n'],
#  ['negative', 'When been sold NRA Monsanto\n'],
#  ['negative', "Monsanto's Roundup not good you #Monsanto\n"],
#  ['negative',
#   "Still that doesn't detract facts Monsanto may be monopolist jerks crops are safe\n"],
#  ['negative',
#   'New post Monsanto wants replace bees they are killing genetically engineered flying ants\n'],
#  ['negative',
#   "Nice Hillary don't want mention Tar Sands Monsanto Arctic Drilling TPP supporting Bernie\n"],
#  ['negative',
#   'LAST thing we need is more corn Monsanto last paragraph says it hot\n'],
#  ['negative',
#   "Monsanto's Roundup herbicide disrupts hormones even glyphosate exposures\n"],
#  ['positive',
#   'Morgan Stanley Rating Update Monsanto Company NYSE MON research note released investors\n'],
#  ['positive',
#   'March Monsanto founder Tami Canal discusses #FoodJustice Anthony Gucciardi\n'],
#  ['negative',
#   'Bwahahaha going March Monsanto lately They claim know research yet have\n'],
#  ['negative',
#   "California May Label Monsanto's Roundup Known Cause Cancer Natural Society well time\n"],
#  ['negative',
#   'March Monsanto sharing info dangers dihydrogen monoxide Scientific literacy is hard\n'],
#  ['negative',
#   'Monsanto running commercial saying they care earth is Isis ad 4th July\n'],
#  ['negative',
#   'OK- then you should have given money back 1st place way Allegations Monsanto are serious Avoid COI\n'],
#  ['positive',
#   'I just want sleep watch Netflix Friday Bulldog Bash Is that so much ask\n'],
#  ['positive',
#   "I don't want girl parties time down watch Netflix order pizza Friday night\n"],
#  ['positive', 'Netflix chill season coming you way\n'],
#  ['positive',
#   'Too hot cold Rain Sun Snow Clear People always have excuse not vote Online you say Nah watching Netflix\n'],
#  ['positive',
#   "5th quarter Netflix is so good sad you should watch it haven't already\n"],
#  ['positive', 'I just bought 5th season stay Netflix lol\n'],
#  ['positive', 'Just found season Arrow is going be Netflix October\n'],
#  ['negative',
#   "Why would Netflix decide fucking audio problem episodes man c'mon! You wouldn't take spoon fiend you\n"],
#  ['positive',
#   'watch Video Games Movie Netflix it starts 1st video game systems now\n'],
#  ['positive',
#   "Tomorrow's Friday I need it Bout lock myself watch Netflix gym time\n"],
#  ['positive',
#   "sad true story Ms. also part reason I cut myself chicas c'mon luv Netflix chillin\n"],
#  ['positive',
#   'I start school tomorrow almost midnight still watching Netflix\n'],
#  ['positive',
#   "you don't support 5th season #Metalocalypse I will be forced give entire dollar fortune Netflix\n"],
#  ['positive',
#   'Tomorrow morning is going come really fast class yet still watching Netflix college\n'],
#  ['positive', 'it may just need happen bring Netflix Start trend #noshame\n'],
#  ['positive',
#   'really bored guys you can tell gonna have Netflix marathon tomorrow suggest things I could watch\n'],
#  ['positive',
#   'Netflix addiction problems midnight I have get early tomorrow want watch everything #notenoughhoursinaday\n'],
#  ['positive', 'Real committed watch Netflix day Wednesday\n'],
#  ['positive',
#   'reason dad is coolest human he currently obsessed friday night lights netflix\n'],
#  ['positive',
#   "not doing nothing tomorrow just gonna sit home watch Grey's Anatomy Netflix\n"],
#  ['positive',
#   'Correction #TheSuicideTheory will be available Netflix TOMORROW U Check it follow\n'],
#  ['positive', 'I got 1st achievement xbox watch Netflix days row\n'],
#  ['positive',
#   "Netflix sleep I have get early tomorrow don't want still recovering T Swift\n"],
#  ['positive', 'Have tomorrow night work hw Netflix chill dog :-)\n'],
#  ['negative',
#   'cancelled Netflix June it has taken payments Who do I contact this\n'],
#  ['positive', 'can we Netflix chill tomorrow instead me going school\n'],
#  ['positive', 'ever seen Friday night lights Netflix you look Lila Gearity\n'],
#  ['positive',
#   'Been rewatching 3rd Rock Sun Netflix Still funny first seasons Have you seen it\n'],
#  ['positive',
#   "I don't have work tomorrow am going watch Netflix stay probably fall asleep decent time anyways\n"],
#  ['positive', 'oh okay u said it was Netflix right Maybe watch Friday\n'],
#  ['positive',
#   'Foxtel is arguing media reform Netflix could buy rights Melbourne Cup seriously\n'],
#  ['positive',
#   'day weekend binge watching old episodes Saturday Night Live Netflix\n'],
#  ['positive', 'Netflix are make more\n'],
#  ['positive', 'she gave me Netflix password crossed base\n'],
#  ['positive',
#   'good excited 3rd season finding home Netflix Just want make sure readers have news it develops\n'],
#  ['positive',
#   'is horror it First season best second dreadful Third ok just waiting 4th Netflix ha\n'],
#  ['positive',
#   'I think Wednesday is day you lay bed watching Netflix eating school shit\n'],
#  ['positive', 'I may have just renewed Netflix wanted rewatch Once Time\n'],
#  ['positive',
#   'I discovered Netflix series you may like Dinos Trucks Dinotrux\n'],
#  ['positive',
#   'Woooohooo Netflix coming Singapore Finally I live country part 21st digital convenience revolution\n'],
#  ['positive',
#   "Yeah data resets tomorrow don't burn it road weekend watching Netflix\n"],
#  ['positive',
#   'may just wear helmet I watch Kevin Hart Netflix lol wife wants go ya know what that means\n'],
#  ['positive',
#   "we may be poor cuddling kitten bed wine chicken wings tacos candle light Netflix isn't worst #netflix\n"],
#  ['positive',
#   'I have much do tomorrow logical thing is watch Netflix day obviously\n'],
#  ['positive',
#   "Oppenheimer's Jason Helfstein reiterated firm's Outperform rating Netflix $NFLX ahead Wednesday's Apple Inc $AAPL\n"],
#  ['positive',
#   'Netflix has eye new markets Asia launch next year said Tuesday it will bring\n'],
#  ['positive',
#   'been library twice times sat swanky chairs watching netflix #lit #collegegoals #woo\n'],
#  ['positive',
#   'going need catch I only just started watching 3rd season accident lol Are 1st seasons Netflix\n'],
#  ['positive',
#   'Longmire premieres tomorrow Netflix Thank you picking season\n'],
#  ['positive',
#   'time sun shines happy when it rains I just wanna cuddle you be warm Netflix chill\n'],
#  ['positive', 'I have this coming Netflix tomorrow Never saw it\n'],
#  ['positive', 'doing nothing 6th hour just gonna watch Netflix :-)\n'],
#  ['positive',
#   'should i read quiz tomorrow procrastinate just watch netflix instead\n'],
#  ['positive',
#   'PS3 is finally here Netflix has returned may procrastination begin\n'],
#  ['positive',
#   'They are more usually seen bars Netflix original series Sunday trio had whale time Billie Jean\n'],
#  ['positive',
#   '#brc222 Interesting going be challenge Apple top Netflix originals #OITNB\n'],
#  ['positive',
#   'You may have seen them Nike Soccer now you can Stop NC has again innovated\n'],
#  ['positive',
#   "Nike's Phil Knight may give training facility University Oregon\n"],
#  ['positive', 'Closer look Nike LeBron What Coming tomorrow\n'],
#  ['positive', 'what time will Anthracite 9s drop tomorrow Nike\n'],
#  ['negative',
#   "Start new job Saturday thank god come fast Nike was way too unorganized me I wasn't fucking it\n"],
#  ['positive', "Use code PUMPED Nike's clearance get extra Ends 7th\n"],
#  ['positive',
#   'I crushed km run pace Nike iPod #makeitcount #nikeplus #september\n'],
#  ['positive', 'Yesterday you said Tomorrow Just do it Nike\n'],
#  ['positive', 'teaming Nike host heck birthday bash Wednesday RSVP here\n'],
#  ['positive',
#   'Check Labor Day Weekend sales going now Monday Nike Clearance Store\n'],
#  ['positive',
#   "Today should be Nike tomorrow Glasgow Edinburgh cycle so won't see Monday work will miss it Tuesday mojo has gone\n"],
#  ['positive',
#   'GOT EM min using SNKRS app Going forward I hope Saturday releases could go as smoothly Thank you Nike\n'],
#  ['positive',
#   'ENDS TOMORROW good stuff is going FAST Extra Nike w/coupon PUMPED\n'],
#  ['positive',
#   'moment when u realize may be single handedly supporting entire Nike corporation can really ever have too much #Nike stuff\n'],
#  ['positive', 'may just be Nike gear everyone also looks larger Core area\n'],
#  ['positive',
#   'little brother comes home nike elite socks jordans when i was 6th grade got wilson clearance shoes Olympia\n'],
#  ['positive',
#   'Check local Nike retail locations release info Only online has been confirmed September\n'],
#  ['positive', 'body come me Nike outlet tomorrow\n'],
#  ['positive',
#   'i need figure what shoes going buy tomorrow NIKE ADIDAS SUPERSTAR BROTHER HAS I WANT HAVE IT\n'],
#  ['positive', 'not Nivia will be associate kit match may nike\n'],
#  ['negative',
#   "Nike has been talking going sweatshop free it still hasn't happened C'mon now\n"],
#  ['negative',
#   "I don't think Nike was ever option Part it may be small inexperienced management team kept around\n"],
#  ['negative',
#   "Nike didn't have what I needed so now need order it online NEED IT TOMORROW\n"],
#  ['negative',
#   'going see how long I can go getting caught wearing Nike shorts tomorrow\n'],
#  ['positive', 'going Nike employee store tomorrow so fucking excited\n'],
#  ['positive', "1st part Nike's very interesting topic genlivecast\n"],
#  ['positive',
#   "I Want be #UltimateNikeFan don't hav Nike Product Hope dey will Send me products So That i may fall love\n"],
#  ['positive',
#   'Seriously can things just go right day Turns Nike run is tomorrow\n'],
#  ['positive',
#   'Put Saturday diary you want pair Nike Air Presto will only be pairs store\n'],
#  ['positive',
#   'Are you interested interning Nike Info Session September McClelland Park RM\n'],
#  ['positive', 'tomorrow is last day Trying decide i wanna go Nike run that\n'],
#  ['positive',
#   'consecutive year #Patriots Nike will release new Lunar Force sneakers\n'],
#  ['positive',
#   'Looks releases Nike Jordan will be raffle I can dig it Fck bots\n'],
#  ['positive', 'Nike trying change online game\n'],
#  ['positive',
#   'it may be younger I loved helmet Nike is giving us money you have experiment little\n'],
#  ['positive',
#   'New Hurley thongs slides featuring Nike free technology sole #treatyourfeet feel sun toes\n'],
#  ['positive',
#   'will u guys be giving tickets Nike flyknit racer coming Friday\n'],
#  ['positive',
#   'tomorrow is picture day just going pretend likei forgot go nike shorts whoopse\n'],
#  ['positive',
#   'I love Nike players Way go Serena Expecting great things you tomorrow federer\n'],
#  ['positive',
#   'Think this is great advertisement Nike it may be unconventional very emotional inspiring #M300F15\n'],
#  ['positive',
#   'light recent Nike drawing announcement online orders we will keep flyknit now refund needed come Friday\n'],
#  ['positive',
#   "Wednesday's Minute Warm chart punts last wknd Pats ower Robert Kraft gets own Nike shoe\n"],
#  ['positive',
#   "#FRESHKICKS Nike's online raffle system may have finally beaten bots #SineadFresh\n"],
#  ['positive',
#   "BAM LIFESTYLE Nike's Online Raffle System May Have Finally Beaten Bots\n"],
#  ['negative',
#   'White girls be so annoying accessories why you wearing striped sun dress Nike hat coach bag\n'],
#  ['positive', 'is it true Nike pushed back ovo release October\n'],
#  ['positive',
#   'Diego sat talks van life Toy Machine new role Nike team dude back Argentina\n'],
#  ['negative', "I don't have money NINTENDO STOP IT\n"],
#  ['positive',
#   'Nintendo releases new 3DS Animal Crossings bundle #klgg #nintendo3ds #gaming\n'],
#  ['positive',
#   'Standard New Nintendo 3DS Coming North America September announced today standard\n'],
#  ['positive',
#   'Xmas Deal Alert Original Nintendo Game Boy Console Games Mad Catz Car Charger End Date Thurs\n'],
#  ['positive',
#   'Officially office hours 8th back pack Nintendo Mario Bross YES Mp3 Bikini\n'],
#  ['positive',
#   'Saturday is annual drinking mario kart tournament UK fancy beers Nintendo feel free come join us\n'],
#  ['negative',
#   "Well after more years I just got copyright notice Nintendo 2nd oldest video culprit Wind Waker's main theme\n"],
#  ['positive',
#   "make him more likely be confirmed #Isaac4Smash #ISAAC4SMASH C'mon Nintendo this is childhoods\n"],
#  ['positive',
#   "Nintendo's policy flagship exclusives are better odds sun going supernova secs\n"],
#  ['negative',
#   '1st party Nintendo games stay stupidly expensive Why is Mario Party still most places Definitely not QUALITY titles\n'],
#  ['positive',
#   'I honestly think Super Mario Bros set is coming Nintendo wanted concentrate development more-similar sets 1st\n'],
#  ['positive',
#   'Super Mario Maker review Daily Dot this is online community Nintendo fans have always wanted\n'],
#  ['positive',
#   "Nintendo celebrates Mario's 30th Anniversary Super Mario Maker Quite possibly best reason own\n"],
#  ['positive',
#   'Golden Sun helped build handheld franchise Nintendo Isaac deserves spot\n'],
#  ['positive', 'Gon get smashed Nintendo kind not drunk Right right\n'],
#  ['positive',
#   'Sure it may not be direct sense Nintendo gives GX support sending coverage press releases\n'],
#  ['negative',
#   'I admit Nintendo may have gone bit overboard whole give popular youtubers copy super mario maker thing\n'],
#  ['negative',
#   'it comes NOV does come Nintendo is notorious rumors trust me ha\n'],
#  ['positive',
#   "I find it interesting 3rd party collector's edition don't sell Nintendo is different story\n"],
#  ['positive',
#   'Just updated profile help promote new game Nintendo 3DS coming September called Animal Crossing Happy Homes\n'],
#  ['positive',
#   'i dont know is that nintendo direct tomorrow probably when were going get right\n'],
#  ['positive',
#   'least it established Nintendo can put 3rd party characters I want Snake back\n'],
#  ['positive', "Tomorrow's Nintendo Know is done going be pretty good time\n"],
#  ['negative',
#   'is certain cult classic game series we have been waiting US Nintendo refuses release it\n'],
#  ['positive',
#   "Honestly lack 3rd party support should have been expected not company's fault siding Nintendo\n"],
#  ['positive',
#   "again improvement I don't like barely Nintendo first party exclusives ALL 3rd systems\n"],
#  ['positive',
#   'then I suppose 3rd party ports suffer maybe Nintendo will use nvidia there gfx chip Lol\n'],
#  ['positive',
#   'Nintendo needs more 3rd party reps same time what makes pure\n'],
#  ['positive',
#   'November Nintendo released Game Boy Color first handheld allowed be owned POC #BullshitHistory\n'],
#  ['positive', 'Anyone want Nintendo arrive Wednesday Star deal\n'],
#  ['positive',
#   "I can't believe Nintendo is announcing NX Just mean why not Here ya go Happy Monday Miyamoto\n"],
#  ['positive',
#   'Nintendo may go back carts also make I can sit console carpet Full N64 style #Nintendo #indiedev\n'],
#  ['positive', 'Nintendo should just pack it go 3rd party not LEAST\n'],
#  ['positive',
#   'Where did you order it Tell me was Nintendo store I can hope turns tomorrow\n'],
#  ['positive',
#   'long shot dream announcement tomorrow Apple TV video games include partnership Nintendo\n'],
#  ['positive',
#   'Nintendo may have wanted make it they left him I dunno probably not true\n'],
#  ['positive',
#   "I bought Rayman Legends just have simple fun can't wait Nintendo sink become 2nd/3rd party developer\n"],
#  ['positive',
#   'It would be poetic Nintendo became Sony Party Developer also make choosing consoles generation very easy\n'],
#  ['positive',
#   "Apparently Super Mario Maker comes September I guess Nintendo's way saying just bloody rebuild them already\n"],
#  ['positive',
#   'What tomorrow Apple is just like TV now game console going take Sony Microsoft Nintendo lol\n'],
#  ['positive',
#   'may everyday look bonus points you get playing Nintendo game Super Mario\n'],
#  ['positive',
#   "Nintendo franchises I wish could be excited Pikman C'mon can't just have Star Tropics\n"],
#  ['positive', 'She still has games Nintendo consoles 4th coming she chance\n'],
#  ['negative',
#   'Nintendo is not going change other system they promise 3rd party support never deliver it\n'],
#  ['positive',
#   "Is tomorrow's new Apple TV really games console does it involve Nintendo thing\n"],
#  ['positive',
#   'Apple also announces acquired Nintendo got fucks give console ambitions they may have\n'],
#  ['positive',
#   'Yeah bro I read long time ago Kojima Metal Gear Solid really wanted series Nintendo 1st\n'],
#  ['positive',
#   '#supermariomaker is Friday excited I absolutely love Nintendo me\n'],
#  ['positive',
#   'u were consider best supported console 3rd parties ex-Sega range games say Nintendo SNES me :)\n'],
#  ['negative', 'Hahahahahahahah no it may be threat Nintendo ;P\n'],
#  ['positive',
#   'Nokia May Be Helpful Microsoft Management analysts have faith reason nonexistence\n'],
#  ['negative',
#   'Replacing screen Nokia went badly Luckily new phone arrives tomorrow\n'],
#  ['positive', 'is phone nokia lumia moto g 3rd gen\n'],
#  ['positive', 'chavvy girl sat opposite end bus arguing Nokia\n'],
#  ['positive',
#   'Come play 15th Ball Challenge you could score Nokia tablet #15thShot #yougotthis\n'],
#  ['positive',
#   'I droped Nokia 5th floor it didnt even hav scratch not exageratin wish new phones had that kinda durability\n'],
#  ['negative',
#   'I think you can longer sync symbian device Nokia account have ceased exist April\n'],
#  ['positive',
#   'phone would want pull shit together Saturday otherwise back Nokia :)))))\n'],
#  ['positive', 'Nokia n95 solidly hand ides march UvQEDAk\n'],
#  ['positive',
#   'Spent Sunday afternoon young cooly Fresh Rio lucky stripes Nokia\n'],
#  ['positive',
#   'It looks Nokia may be positioning strong return mobile hardware market following license\n'],
#  ['positive',
#   'I finally got moto g 3rd gen camera is not good Nokia lumia 720 there something wrong unit\n'],
#  ['positive', 'big fan early i was using Nokia still easy use affordable\n'],
#  ['positive',
#   "Back day we used put Nokia batteries sun they wud charge just fine Today's phones are dumber ever\n"],
#  ['positive',
#   "mobile game Snake may end being most lucrative part Microsoft's Nokia purchase\n"],
#  ['negative',
#   'it has been more week as usual updates nokia 2nd long hibernation service center :)\n'],
#  ['positive',
#   'sim is active may we know response you are getting kindly insert Nokia phone preferably\n'],
#  ['positive',
#   'Nokia seeking innovative ideas IoT Winners innovation challenge may receive VC funding\n'],
#  ['positive',
#   'Facebook just achieved active users day Monday peak people carried Nokia phone them\n'],
#  ['positive', '#HAMILY help tear club nokia october be littt\n'],
#  ['positive', 'wow i had first phone 6th grade it was nokia express music\n'],
#  ['positive',
#   'Nokia n97 microcosm bear whole direct utterly comprehensive march\n'],
#  ['positive',
#   'Nokia n97 miniature whole range green simply entire march kwCauf\n'],
#  ['positive', 'September Nokia live Los Angeles going\n'],
#  ['positive',
#   "BBRY's route is more similar Nokia both had great market share in-house OS then going 3rd party\n"],
#  ['positive',
#   '4th Nokia XpressMusic Fact This have Stylus Used hate Touchscreens cellphones this\n'],
#  ['positive',
#   '5th Nokia Lumia first Windows Phone Fact This made me earn Win Fanboy title friends\n'],
#  ['positive',
#   "6th Nokia Lumia Fact friends call it Phablet They didn't even see phones\n"],
#  ['positive',
#   'terribly tempted move back Nokia phone I may still use it hotspot\n'],
#  ['positive',
#   'I last charged Nokia brick phone friday Todays monday only now does it say battery low\n'],
#  ['negative', 'phone may as well be Nokia it none apps are working\n'],
#  ['positive',
#   'classic Nokia spare covers Dad gave it me 21st Major excitement\n'],
#  ['positive', 'Soon Foxconn Chennai facility Nokia used pay Apple China\n'],
#  ['positive',
#   "Apparently I have new Moroccan boyfriend He doesn't speak English we just sat Nokia played snake Best relationship ever\n"],
#  ['positive',
#   'Happy 15th Birthday You are still greatest mobile phone ever made Ladies gentlemen Nokia\n'],
#  ['positive',
#   'Nokia N1 Tablet Receiving Android Lollipop Upgrade most popular tablets available mar\n'],
#  ['positive', 'Happy 15th birthday greatest mobile phone time Nokia\n'],
#  ['positive',
#   'OMG 15th birthday Nokia I had Sigh You only charge battery weekly\n'],
#  ['positive', 'Happy 15th Nokia best phone ever :3\n'],
#  ['positive',
#   'Thank U Nokia Yesterday Was 15th Birthday Best things has Ever Happened\n'],
#  ['positive',
#   'Long life pros Happy 15th birthday legendary Nokia father mobile phones\n'],
#  ['positive',
#   'Pretty sure kids me know where that is coming unveiling Nokia ahem I mean 1st iPhone\n'],
#  ['positive', 'Looks someone agrees you Was Nokia greatest phone time\n'],
#  ['positive', 'Happy 15th Birthday Nokia you are missed\n'],
#  ['positive',
#   'Phablet designs Nokia Lumia iPhone Plus Samsung Galaxy S6 Edge Saturday I got play\n'],
#  ['positive', 'yea still nokia i just kinder phone 7th times am usin it\n'],
#  ['positive',
#   "I was island could only have thing it may not be solar powered stereo John Mayer's Live Nokia\n"],
#  ['positive',
#   'need surprise mom OP2 b day which is sept send invite pls she s using nokia 6203\n'],
#  ['positive',
#   'Seriously England qualifier looks being filmed crappy Nokia phone Feels watching Sunday league football\n'],
#  ['positive',
#   'Hi Robert Nokia may be best answering this you could try reset here\n'],
#  ['negative',
#   'Mom case may be most strongest cases possible it feels holding using fucking NOKIA\n'],
#  ['positive',
#   'Nokia is returning phone business time Android Catch News Back June Rajeev\n'],
#  ['positive',
#   'BASIC NEEDS what part this dont U understand I just said communication may be EVENTUALLY important Get euro Nokia\n'],
#  ['positive',
#   "Beckham kids may get everything they want won't know feeling playing snake old nokia phones\n"],
#  ['positive',
#   'Rumours had it long this may actually be first Nokia Android phone\n'],
#  ['positive',
#   'hey turns Obama may be right man made climate change destroying planet #IranDeal :-p\n'],
#  ['negative',
#   "How will be hard beat guy's Obama's 3rd term not very bright CONSERVATIVE Repub kick Dem ass\n"],
#  ['negative',
#   'girly technique CUTE may be going style distraction national will It led Obama we can see fruits\n'],
#  ['positive',
#   'I am not American convinced Obama 11th president lifetime is far best\n'],
#  ['negative',
#   "Y #FireBoehner He fully funded Obama's #amnesty #IllegalAliens back February campaigning promise stop amnesty #tcot\n"],
#  ['positive',
#   "Obama's day Duke Blue Devils President Obama opens post-Labor Day week Tuesday welcoming\n"],
#  ['positive',
#   'watching obama videos i need fucking break just tuesday thank god\n'],
#  ['positive',
#   'Carly Fiorina may make inroads Dem support she Dems initiatives including admitting Obama did good\n'],
#  ['negative',
#   'we hand her US Supreme Court stack handed Obama term turn lights\n'],
#  ['negative',
#   'Obama Cameron Who taught you draw kill list YOU ALRIGHT I LEARNED IT WATCHING\n'],
#  ['negative',
#   'real sustained #WarOnWomen regime Obama is giving $$ nuke capabilities May God forgive us\n'],
#  ['positive',
#   "Senate Dems secure Obama's Iran nuclear deal Democrats Tuesday gave President Barack Obama votes he needs\n"],
#  ['negative', 'Obama is putting US par other 3rd world country\n'],
#  ['negative',
#   "Doomsday may be sooner you think Obama's signed Iran Deal Don't fret HilLIARy history year\n"],
#  ['negative',
#   "debating skipping class tomorrow I don't wanna deal crazy people Obama\n"],
#  ['negative',
#   "why Obama's personal records are sealed Executive order Only guilty party take 5th\n"],
#  ['negative',
#   "Cheney could say is Obama's fault classic Iran started nuke program Jan\n"],
#  ['negative',
#   'that may be Obama has gotten us hell mess makes it worse daily failed policies kumbaya\n'],
#  ['negative',
#   'you violate restraining order have go jail it may be deputy voted Obama #TheMoreYouKnow\n'],
#  ['negative',
#   "Want fight Obama's terrible #IranDeal Help us send message joining Capitol tomorrow\n"],
#  ['negative',
#   "Big Rally tomorrow again it looks too little late Where was everyone Kerry Obama F'ed\n"],
#  ['negative',
#   'Follow money that $150B release Iran is going Obama account Think it\n'],
#  ['positive',
#   "Given Obama's usual sense urgency Washington's review Syrian refugee not migrant crisis may be\n"],
#  ['negative',
#   'I spoke Trumps campaign today told colleges how Obama won Carson moving got email Iowa st sat said bring\n'],
#  ['negative',
#   'Was there ever doubt Democrats would march lockstep Obama rather constituents\n'],
#  ['positive',
#   "US Public Agrees Israel's Opposition Iran Deal Obama may have secured congressional support\n"],
#  ['negative',
#   "Sarah Palin joining Donald Trump Ted Cruz big rally D.C. tomorrow PM Capitol protest Obama's insane Iran nuke deal\n"],
#  ['positive', 'Bibles guns Obama was right 1st time\n'],
#  ['negative', "We don't want Obama dumping them USA\n"],
#  ['negative',
#   "Obama was adopted Dumham's husband Soetero name changed Barry record it Bj\n"],
#  ['positive',
#   "Just wondering more Senators voted Iran deal today Obama doesn't even need veto why is rally it tomorrow\n"],
#  ['negative',
#   'caution 1st problem caused Cautious Syria war Obama now cautious refugee crisis CSM\n'],
#  ['negative',
#   "AS far I am concerned you Murdered Stevens Obama's help Bring him down sentence may be lighter You played part Murder\n"],
#  ['negative',
#   "Tomorrow I pray Persian people will stand Trump Washington stop Obama's nuclear insanity\n"],
#  ['negative',
#   'matter why you go war what do victory does just look it burn now Obama may have started fire big control\n'],
#  ['negative',
#   "Fractured got me thinking Could part Bernie's surprised rise be sense Hill may move party back right Obama\n"],
#  ['negative',
#   "We people must do whatever it takes fight Obama's lawlessness communist bent destroying heritage NOW NOT TOMORROW\n"],
#  ['positive', 'Obama is making trip Des Moines Monday You coming it\n'],
#  ['positive', 'Obama may be President free world King dad jokes\n'],
#  ['negative',
#   "Mark Levin Market Crash Not China-It's Barak Obama belief is working China destroy USA\n"],
#  ['negative',
#   'Russia may be take ISIS down Syria Assad get support soon Turkey collide too Obama failed\n'],
#  ['positive',
#   "Obama's 94-year-old grandmother will be honoured work Kenya's orphans 10th South African Traditional Music Awards\n"],
#  ['negative',
#   'Iran was biggest supporter terrorist obama pushed them 1st place\n'],
#  ['negative',
#   'Obama controlling where you get live move making choices Government Loans You may use\n'],
#  ['negative',
#   'Remember Hillary denied server existed ever day liar President Obama Country will not survive\n'],
#  ['negative',
#   'rather be strong we can lift others Obama doctrine seems make USA unsecured chaotic 3rd World\n'],
#  ['positive', 'Enjoy Fun Fly Green Park Obama is fan\n'],
#  ['negative',
# ...
#   'recent pro gay marriage decision SCOTUS has directly violated 9th 10th amendments United States Constitution\n'],
#  ['negative',
#   "Clerk #KimDavis is jailed SCOTUS can see Gay Marriage 14th Amend Fed Dist Judge can't religious freedom 1st\n"],
#  ['negative',
#   "Congress can't make law preventing religious freedom SCOTUS interpretation unlawful Const Trumps case\n"],
#  ['negative', 'scary is that it was only SCOTUS Irving may flip vote\n'],
#  ['negative',
#   '14th amendment is also attack do we chose oh yeah SCOTUS they ruled\n'],
#  ['negative',
#   'Searching marriage 14th Amendment how SCOTUS usurp powers it does not have Constitution\n'],
#  ['positive',
#   'was declared unconstitutional SCOTUS violation 14th Amendment so been settled\n'],
#  ['positive',
#   'SCOTUS never made law they interpreted it guarantees equal rights Americans\n'],
#  ['negative',
#   "panthers are advocating killing police SCOTUS says that true threats 1st Amendment why aren't\n"],
#  ['negative',
#   'SCOTUS vitiated KY marriage law immediately it violated 14th Amendment\n'],
#  ['negative',
#   'U sound hated smartset now Is #KimDavis 1st ignore unlawful ruling SCOTUS history\n'],
#  ['negative',
#   'Huckabee claims SCOTUS made new law SSM No equal protection clause 14th Amendment is more century old\n'],
#  ['negative',
#   'SCOTUS cannot make law only rule it Get real America healthcare Then they feel can\n'],
#  ['negative',
#   'SCOTUS Apparently is Saying Gays Have Equal Right Marriage 14th Amendment\n'],
#  ['negative',
#   'Ohio has defined marriage man woman SCOTUS now writes law guess you may marry who/what wish\n'],
#  ['positive',
#   'I may have missed it u posted take #KimDavis situation claims SCOTUS ruling\n'],
#  ['positive',
#   'You are aware SCOTUS said it fell sections 14th Admendment right\n'],
#  ['positive', 'Seinfeld when Kramer is lost confused corner 1st\n'],
#  ['positive',
#   'you wanna watch Big Bang Theory tomorrow TBS Seinfeld Should be good\n'],
#  ['positive',
#   'Seinfeld may have not known it time he made last sitcom mattered\n'],
#  ['positive',
#   'Let it be know that enjoys Seinfeld I may have had force her watch episodes she has chosen enjoy them\n'],
#  ['positive',
#   "see Ant Man I don't expect it be as good Bug's Life Antz Seinfeld's Bee Movie may BEE surprised\n"],
#  ['positive', 'Seinfeld may be best shows time\n'],
#  ['positive', 'Seinfeld tonight tomorrow night that\n'],
#  ['positive', 'Someone come see Seinfeld me November\n'],
#  ['positive',
#   'Seinfeld fans get winner #DelMar Little Jerry wins thriller 7th\n'],
#  ['positive',
#   'Nothing rainy Sunday coffee Seinfeld reruns right amount laziness\n'],
#  ['positive',
#   'editor episodes Seinfeld was named Skip Collector That may be best name editing\n'],
#  ['positive',
#   "Rick Perry debating Seinfeld character refers himself 3rd person Jimmy's gettin angry\n"],
#  ['positive',
#   "Thursday night Must-See TV hasn't been comical Friends Seinfeld punch #GOPDebate\n"],
#  ['positive',
#   'Twitter account Seinfeld episode where they talk themselves 3rd person\n'],
#  ['positive',
#   'Happy 60th birthday actor Wayne Knight Seinfeld Third Rock Sun you may sight\n'],
#  ['positive',
#   'Happy 60th Birthday Wayne Knight Newman Seinfeld he also played Officer Don 3rd Rock\n'],
#  ['positive',
#   'Nothing watching episodes Seinfeld Sunday morning Seen humorous slant is different time Magic\n'],
#  ['positive', 'Just got tickets see Seinfeld next Friday Fuck me\n'],
#  ['positive', 'go back shell LMAO dancing might be new Elaine Seinfeld\n'],
#  ['positive', 'I see is Seinfeld logo\n'],
#  ['positive',
#   "Rewind Wednesday Did you know that there were Nintendo Super games Seinfeld's apartment\n"],
#  ['positive',
#   'Keith Hernandez Seinfeld was best appearance athlete TV show movie is Mark McGuire Mad You\n'],
#  ['positive', 'Plus I got Seinfeld DVD killed math section SAT\n'],
#  ['negative',
#   'I told someone how once sat floor hotel room watched Seinfeld hours they threatened punch me\n'],
#  ['positive',
#   'Sun took away energy I want cold pressed juice wanna watch Seinfeld home\n'],
#  ['positive',
#   "TBS playing Comeback episode Seinfeld again Should I bust Jerk Store line tomorrow night's debate\n"],
#  ['positive', 'watch episodes Seinfeld work is over fuck 3rd shift\n'],
#  ['positive', 'well Seinfeld is sun comedies :p\n'],
#  ['positive',
#   "quote Seinfeld's Kramer Monday has feel Wed FRIDAY feeling first Friday school year\n"],
#  ['positive',
#   'Popcorn Seinfeld sounds perfect friday night #ithinkimgettingold\n'],
#  ['positive',
#   'Someone needs make Video Compilation SAT vocabulary Cosmo Kramer spontaneously uses Seinfeld\n'],
#  ['positive',
#   'Will watch old movies Seinfeld other silly things Sunday #katrina news footage is too much heart bear\n'],
#  ['positive',
#   "may be hard believe I am watching Seinfeld's Contest very first time\n"],
#  ['positive', 'Netflix Hulu stats Seinfeld still killing it\n'],
#  ['positive', 'Stay late watch Seinfeld make Steve drive tomorrow\n'],
#  ['positive',
#   'Which surface may seem counterintuitive marginal utility Seinfeld obviously increases increasing rate\n'],
#  ['positive', 'Love Seinfeld episode picture\n'],
#  ['positive',
#   "George's stories may be favorite thing Seinfeld he is so passionate wonderful\n"],
#  ['positive',
#   'Blazers have been cemented new team based solely how much Seinfeld fan Neil Olshey is #cartwright\n'],
#  ['positive',
#   'World I think it may be time accept that nothing Larry David did Seinfeld has been funny\n'],
#  ['negative',
#   'finding life dialogue me are right Seinfeld episode Many you may think this is fun unnerving\n'],
#  ['positive',
#   "Won't be live tweeting vma's tonight what you may have guessed Watching Seinfeld instead Thank\n"],
#  ['positive', 'yes maybe reference not sure anyone got Seinfeld Wednesday\n'],
#  ['positive',
#   'Magic Loogie is cleverest scenes Seinfeld ever Tuesday evening pleasure\n'],
#  ['positive', 'may be greatest thing seen awhile just Seinfeld is show\n'],
#  ['positive', 'Seinfeld may be only thing I care anymore\n'],
#  ['positive',
#   'you wanna drink beers chat Seinfeld Bristol Tuesday Yeh Sweet\n'],
#  ['positive',
#   'Coffee you Meet Larry Thomas Soup Nazi Seinfeld City News Sept he\n'],
#  ['positive',
#   'will be listening work tomorrow You invoke name Seinfeld I expect greatness\n'],
#  ['positive',
#   'Gonna watch Seinfeld smoke joint pass hell going back work jobs again tomorrow #adultshit\n'],
#  ['positive',
#   'Get tickets see Seinfeld He can still make you laugh performing next Friday\n'],
#  ['positive', 'Given love Kanye Seinfeld I think you may dig this\n'],
#  ['positive',
#   "Seinfeld's contest may just be best episodes #andthenthereweretwo\n"],
#  ['positive',
#   'what waste It even has last man earth Seinfeld South Park Monday night raw Hulu is awesome\n'],
#  ['positive',
#   'he is shirking gap him Eddie year one catching Seinfeld may catch\n'],
#  ['positive',
#   'now back day I watched good bit Friends Seinfeld 3rd Rock show got older not much\n'],
#  ['positive',
#   'Little brother just asked me down binge watch Seinfeld goes Sunday night lolol\n'],
#  ['positive',
#   'So like he missed Seinfeld Friends think I was really starting dude\n'],
#  ['positive',
#   'Hulu you say This Seinfeld alone may be worth reactivating subscription\n'],
#  ['positive', 'I may have read that way Seinfeld greeted Newman\n'],
#  ['positive',
#   'I also thought Seinfeld episode hair going 6th grade class photo\n'],
#  ['positive',
#   'haha Seriously though it reminds me Seinfeld character Jimmy liked worship Sunday #chsocm\n'],
#  ['positive',
#   'something has been bugging me lately What Seinfeld was current day brand new episodes came Thursday\n'],
#  ['positive',
#   'Interested see kind ratings U.S. Open final gets Saturday Serena presumably going history CFB\n'],
#  ['positive',
#   'pretty sure Serena ripped match winning same time USMNT game 3rd\n'],
#  ['positive', "Serena's 11th she wins match sister Venus\n"],
#  ['positive', "History still making Serena's win sister Venus #GrandSlam\n"],
#  ['positive',
#   'I love Nike players Way go Serena Expecting great things you tomorrow federer\n'],
#  ['positive',
#   'Serena just needs win more matches last majors/4 single year/last us opens\n'],
#  ['positive',
#   'Serena reaches 7th semifinals #USOpen row more matches complete Grand Slam\n'],
#  ['positive',
#   'Venus missed so many neutral shots 3rd set she never let Serena feel pressure her hook way\n'],
#  ['positive',
#   'Serena won big sister Venus gave her flux Congrats both them giving us great tennis match\n'],
#  ['positive',
#   '5th meeting sisters US Open Serena defeats Venus advance semis\n'],
#  ['positive', 'Serena has mercy sister 3rd set match #USOpen\n'],
#  ['positive', 'It played Serena took set form Vika MIGHT make pay Might\n'],
#  ['positive',
#   'Dem born Venus come Serena top Blessings May children always excel make us proud #USOpen\n'],
#  ['positive', 'Happy Serena I want her win GS tie Steffi CYGS #usopen\n'],
#  ['positive',
#   'I hope young girl watched Williams sisters tonight Serena may have won go down greatest sibling duo ever\n'],
#  ['positive', 'Answer Moi Question seeing Serena play semifinals Thursday\n'],
#  ['positive',
#   'Serena be lettin oponents comeback set just make media feel better good #SerenaVsVenus\n'],
#  ['positive',
#   'Sisterly love beating older sis Venus 3rd set match Serena says best person I know Cc\n'],
#  ['positive',
#   'weird is Serena Venus are train ride away right now I feel they goddesses who live sun\n'],
#  ['negative',
#   'Serena may have taken match Venus wins So much class Just good person same cannot be said sister #veealways\n'],
#  ['positive',
#   'Serena remains top younger Williams bts Venus sisters GS matchup\n'],
#  ['positive',
#   "man enough admit I proudly couldn't handle Serena's back shot Babygirl may have skrongest thigh/a$$ muscles world\n"],
#  ['positive',
#   "Can't take disrespect ppl show Venus best women's draw-wins set Serena say fixed Such BS #SerenavsVenus\n"],
#  ['positive',
#   'Serena won Cubs are winning St. Louis enjoying sports lately Too bad Bears play Sunday\n'],
#  ['positive', 'Go get it Serena Congrats\n'],
#  ['positive',
#   'Serena Williams has won 16th match Venus tonight attempts reach Grand Slam\n'],
#  ['positive',
#   'U.S. Open Features Familiar Matchup Serena Venus Williams Meet 27th Time\n'],
#  ['positive', '27th Williams vs match Serena saved best last\n'],
#  ['positive',
#   'Ok Serena may have won Venus wore hoops match you know how I feel\n'],
#  ['positive', 'you will be procrastinating see Serena make history sunday\n'],
#  ['positive', 'Serena dominated end tough match win\n'],
#  ['positive',
#   'Know scary Serena was mildly injured little Wimbledon sat US Open She could win formula\n'],
#  ['positive', 'feeling Serena could win straight set Venus viewers she let\n'],
#  ['positive',
#   "Now that calmed watching Serena Do you realize how great tomorrow's Vika-Simona match is gonna be\n"],
#  ['positive',
#   'Serena Overpowers Venus Reach 10th US Open SF Azarenka v Halep Wednesday still has upper hand\n'],
#  ['positive',
#   'Team Venus Serena night Williams Tuesday evening home-country #tennis #USOpen\n'],
#  ['positive',
#   'Serena beat sister Venus quarter finals She is matches away 4th successive Grand Slam row #USOpen2015\n'],
#  ['positive',
#   'Serena Tops Venus U.S. Open Williams squeaked quarterfinals Tuesday\n'],
#  ['positive',
#   'Venus was serving passing better she donated UFEs 3rd set Serena played big points win #USOpen2015\n'],
#  ['positive',
#   'Throwback Tuesday Venus vs Serena Wimbledon last time Williams sisters played other was\n'],
#  ['positive',
#   'So 27th chapter Serena vs Venus sees younger Williams move wins #SWeep15 it took sets do #USOpen\n'],
#  ['positive',
#   'serena won Q/final match venus she will play unseeded italian roberta vinci semis Thursday #USOpen2015\n'],
#  ['positive',
#   'Sept Reuters Factbox Americans Serena Venus Williams who will meet quarter-final U.S. Open Tuesday BORN\n'],
#  ['positive',
#   'LINK- Wins Go Serena 27th time Venus Williams stepped court dazzle\n'],
#  ['positive',
#   '#usopen case you fell asleep Serena beats Venus sets lopsided Djokovic wins 4th set tie-break Lopez Celic Vinci\n'],
#  ['positive',
#   '#usopen Venus Williams middle name is Ebony Starr last major Wimbledon d Serena all-time tied Henin Goolagong\n'],
#  ['positive',
#   'Bitter /Sweet Serena may almost not have wanted win father Richard always taught them do best they can\n'],
#  ['positive',
#   "Couldn't hang stay watch 3rd set it was nice see Serena beat Venus What resilient tough player is tho\n"],
#  ['positive',
#   "Best moment air Tue you look down me I don't smoke KS Yeah C'mon Gary watch Serena\n"],
#  ['positive', 'def not She made slight run 3rd serena was too much already\n'],
#  ['positive',
#   "Serena's 1st 3rd set were gracious especially when she hit split slammed it end Sheesh\n"],
#  ['positive',
#   "#usatoday No Serena didn't throw set Venus Forget conspiracies #sports #sportsnews\n"],
#  ['positive',
#   'Meeting 27th time professionals overall Serena Venus Williams faced-off\n'],
#  ['positive',
#   'Thankfully I will be going USOpen Finals this Sat prayerfully see Serena make history\n'],
#  ['positive', 'Going U.S. Open Thursday I hope Serena wins tonight\n'],
#  ['positive',
#   "I really hope Obama attends Serena's match Saturday Ciara's doing National Anthem Give us deze ratings biches\n"],
#  ['positive',
#   'Kendall Gigi Were Definition Sporty-Chic US Open Serena Venus Williams may be most\n'],
#  ['positive', 'Did u see Aces she had set serena Venus still got it folks\n'],
#  ['positive',
#   'Was wondering ratings Maybe final featuring Serena will top this Have think yes\n'],
#  ['positive',
#   'Completely agree Serena tanked set let Venus win then she turned it\n'],
#  ['positive',
#   "wants get away Hope Rafe station Serena's murder gets flowers Aiden 6th time\n"],
#  ['positive',
#   'Yesterday Venus Serena Williams faced 5th time US Open quarter finals what\n'],
#  ['positive',
#   'Azarenka Halep I believe person who may give Serena hard time will come match\n'],
#  ['positive',
#   'Snoop Dogg headlines Tribal Sessions tomorrow he will be bringing old school Hip Hop summers vibes\n'],
#  ['positive', 'Imagine going home Sunday missing Snoop Dogg hahahaha\n'],
#  ['positive', 'I may be love Snoop Dogg\n'],
#  ['positive',
#   'Is drake man enoff diss snoop Dogg I bet he will be dead sun down Uncle snoopy takes shit\n'],
#  ['positive',
#   'going see Snoop Dogg DJ Snoopadelic dj tomorrow Sankeys matters\n'],
#  ['positive',
#   "high schoolers tomorrow you get approached anyone don't want talk just tell them ideal hangout Snoop Dogg\n"],
#  ['positive', "serious you talking lyrics snoop Dogg there Dr dre c'mon\n"],
#  ['positive', 'Martha Stewart smoked weed Snoop Dogg dreams come true\n'],
#  ['positive',
#   'I live minutes there fact dads company is sponsored it seeing Snoop Dogg Saturday :)\n'],
#  ['positive',
#   "Seems Snoop Dogg may need make way title World's Greatest #Stoner certain W Shakespeare\n"],
#  ['positive',
#   'moon is errant thief pale fire she snatches sun Esteemed romantic poet Snoop Dogg\n'],
#  ['positive',
#   "parents are going Musikfest Saturday said they won't go see Snoop Dogg officially not daughter anymore\n"],
#  ['positive', 'Whoop DJing same stage Snoop Dogg just not time lol\n'],
#  ['positive',
#   'ATTENTION good buddy ole pal is looking someone go him see Snoop Dogg tomorrow night please inquire ASAP\n'],
#  ['negative',
#   'ESPN did whole documentary Snoop Dogg son he quit team 1st game\n'],
#  ['positive',
#   'Joakim Noah may have grown France he was still big fan Dr. Dre Snoop Dogg\n'],
#  ['positive', 'I may have unfollow you spelling Snoop Dogg only G\n'],
#  ['positive',
#   'Hey Keith I have same birthday you October We also share birthdays Tom Petty Snoop Dogg\n'],
#  ['positive',
#   "Okay clarification maybe not Snoop Dogg's best song top I was listening it when tweeting so may have been little bias\n"],
#  ['positive',
#   "Snoop Dogg is cool come see THRILL COLLECTIVE 29th I promise you won't regret it haha\n"],
#  ['positive', 'I predict feel partied Psy Snoop Dogg tomorrow\n'],
#  ...]

# %%
f1 = open('C:\\Users\\user\\Desktop\\nlp\\ark-tweet-nlp-0.3.2\\sentiment-analysis\\data\\input\\topic.2class.txt', 'r')
l = f1.readlines()
f1.close()
a= [];
print(len(l))
for  i  in  range ( len(l) ): 
    a.append(l[i].split('\t'))
topics = set();
for i in range(len(arr)):
    topics.add(a[i][1]);
# Out:
# 5416

# %%
file = open('C:\\Users\\user\\Desktop\\nlp\\ark-tweet-nlp-0.3.2\\sentiment-analysis\\data\\output\\mutualExclusive.2class.txt',"w") 
for  topic  in  topics: 
    file.write(topic);
    for i in range(len(arr)):
        if a[i][1]==topic :
            file.write(arr[i][0]);            
            file.write("\t");
            file.write(arr[i][1]);
file.close();
