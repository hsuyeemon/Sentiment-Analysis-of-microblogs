# %%
import subprocess

# %%
f = open('C:\\Users\\user\\Desktop\\nlp\\ark-tweet-nlp-0.3.2\\examples\\topic.2class.txt', 'r')
lines = f.readlines()
f.close()

# %%
arr= [];
for  i  in  range ( len(lines) ): 
    arr.append(lines[i].split('\t'))
print(len(lines))
# Out:
# 5420

# %%
arr
# Out:
# [['638061181823922176',
#   'michael jackson',
#   'positive',
#   'Jay Z joins Instagram with nostalgic tribute to Michael Jackson: Jay Z apparently joined Instagram on Saturday and.. http://t.co/Qj9I4eCvXy\n'],
#  ['638125563790557184',
#   'michael jackson',
#   'positive',
#   "18th anniv of Princess Diana's death. I still want to believe she is living on a private island away from the public. With Michael Jackson.\n"],
#  ['638162155250954241',
#   'michael jackson',
#   'positive',
#   "@etbowser do u enjoy his 2nd rate Michael Jackson bit? Honest ques. Like the can't feel face song but god it's so obvious they want MJ 2.0\n"],
#  ['638180878594785280',
#   'michael jackson',
#   'positive',
#   '@MariahCarey may he R.I.P. Happy Birthday Michael Jackson . :)\n'],
#  ['638185679948660736',
#   'michael jackson',
#   'positive',
#   'I just may be actually done with this award show.. Unless they get Michael Jackson on hologram.\n'],
#  ['638201443044868096',
# ...

# %%
#file = open("C:\\Users\\user\\Desktop\\nlp\\ark-tweet-nlp-0.3.2\\examples\\dataIn.txt","w") 
#file.write("HEllo WOrld") 
#file.close()

# %%
file = open("C:\\Users\\user\\Desktop\\nlp\\ark-tweet-nlp-0.3.2\\examples\\tweets.txt","w") 
for  i  in  range ( 3000): 
    text = arr[i][3];
    file.write(text) 
file.close()

# %%
p = subprocess.check_output('java -XX:ParallelGCThreads=2 -Xmx500m -jar ../ark-tweet-nlp-0.3.2.jar ../examples/tweets.txt')
print(p)
# Out:
# b'Jay Z joins Instagram with nostalgic tribute to Michael Jackson : Jay Z apparently joined Instagram on Saturday and .. http://t.co/Qj9I4eCvXy\t^ ^ V ^ P A N P ^ ^ , ^ ^ R V ^ P ^ & , U\t0.9995 0.9812 0.8313 0.9776 0.9953 0.9940 0.9931 0.9982 0.9998 1.0000 0.9110 0.9998 0.9630 0.9941 0.8434 0.9414 0.9932 0.9949 0.9979 0.9006 0.9980\tJay Z joins Instagram with nostalgic tribute to Michael Jackson: Jay Z apparently joined Instagram on Saturday and.. http://t.co/Qj9I4eCvXy\r\n18th anniv of Princess Diana\'s death . I still want to believe she is living on a private island away from the public . With Michael Jackson .\t$ N P ^ Z N , O R V P V O V V P D A N R P D N , P ^ ^ ,\t0.5002 0.9780 0.9979 0.9242 0.8786 0.9948 0.9980 0.9958 0.9883 0.9991 0.9897 0.9996 0.9993 0.9996 0.9424 0.9329 0.9959 0.8321 0.9524 0.9705 0.9997 0.9990 0.6251 0.9983 0.9815 0.9998 1.0000 0.9949\t18th anniv of Princess Diana\'s death. I still want to believe she is living on a private island away from the public. W
# ...

# %%
tokenizedText = open("C:\\Users\\user\\Desktop\\nlp\\ark-tweet-nlp-0.3.2\\examples\\tokenizedTweet.txt","w") ;
file.write(p) ;
file.close()
