# %%
import subprocess
import numpy as np



p = subprocess.check_output('java -XX:ParallelGCThreads=2 -Xmx500m -jar ../ark-tweet-nlp-0.3.2.jar ../examples/sample.txt')

# %%
print (p)
# Out:
# b'638061181823922176\t!\t0.2098\t638061181823922176\tmichael jackson\tpositive\tJay Z joins Instagram with nostalgic tribute to Michael Jackson: Jay Z apparently joined Instagram on Saturday and.. http://t.co/Qj9I4eCvXy\r\n638125563790557184\t!\t0.2091\t638125563790557184\tmichael jackson\tpositive\t18th anniv of Princess Diana\'s death. I still want to believe she is living on a private island away from the public. With Michael Jackson.\r\n638162155250954241\t$\t0.2708\t638162155250954241\tmichael jackson\tpositive\t@etbowser do u enjoy his 2nd rate Michael Jackson bit? Honest ques. Like the can\'t feel face song but god it\'s so obvious they want MJ 2.0\r\n638180878594785280\t$\t0.3497\t638180878594785280\tmichael jackson\tpositive\t@MariahCarey may he R.I.P. Happy Birthday Michael Jackson . :)\r\n638185679948660736\t!\t0.2098\t638185679948660736\tmichael jackson\tpositive\tI just may be actually done with this award show.. Unless they get Michael Jackson on hologram.\r\n638201443044868096\t!\t0.2098\t638201443044868096\tmichael jackson\tpositive\t@NICKIMINAJ today you try to destroy a Sir Mix-a-Lot hit - tomorrow Michael Jackson? WRITE YOUR OWN DAMN HOOKS!\r\n638201499118497792\t!\t0.2215\t638201499118497792\tmichael jackson\tpositive\tVIRGO OF THE DAY- We wished our fellow Virgo Captain Michael Jackson a Happy Birthday on the 29th now it\'s time... http://t.co/fF7I7D7ItV\r\n638209380983414784\t!\t0.2091\t638209380983414784\tmichael jackson\tpositive\t@juliaanapp you may say oh it is August 29 Liam from One Direction\'s birthday but no it\'s also Michael Jackson birthday\r\n638217759826964481\t$\t0.2708\t638217759826964481\tmichael jackson\tpositive\tMichael Jackson was the man, I remember watching the Thriller &amp; Smooth Criminal music video for the 1st time &amp; it was lit\r\n638248645104640000\t$\t0.3709\t638248645104640000\tmichael jackson\tpositive\tALDUB RADIO MaAlden Monday NP: I Just Can\'t Stop Loving You by Michael Jackson! This with Spanish and French versions! #ALDUBTheREVELATION\r\n638299266876854273\t!\t0.2058\t638299266876854273\tmichael jackson\tpositive\t#NP Michael Jackson - Human Nature on #BrunchInTheCiti w/ @OsKwame  #tunein  5th of 7 tracks from the Thriller album http://t.co/pDIlytllfb\r\n638334082850488320\t$\t0.3497\t638334082850488320\tmichael jackson\tpositive\tHappy 28th anniversary to the album that generated 5 #1\'s just like katy\'s teenage dream a.k.a. Bad (Michael Jackson)\r\n638373842138722304\t!\t0.2091\t638373842138722304\tmichael jackson\tpositive\tThe Weeknd may be Michael Jackson reincarnated... I\'m just saying there are a lot of similarities musically #butthatsnoneofmybusiness\r\n638376878168903681\t$\t0.2708\t638376878168903681\tmichael jackson\tpositive\t@OU_Football Eric, I heard your love for Michael Jackson. I got to see him in concert from the 4th row - his sweat hit me when he spun.\r\n638423648492220417\t!\t0.2118\t638423648492220417\tmichael jackson\tpositive\t@Pearsey you got that from his website. My brothers mate at school once said his 2nd cousin was Michael Jackson. A similar tale to this...\r\n638433904131641344\t!\t0.2091\t638433904131641344\tmichael jackson\tpositive\tVery sad news Dr. Wayne Dyer passes away - Ever the Vanguard for Michael Jackson - May God grant him Peace.  https://t.co/bKrxnEou0l\r\n638491441988304896\t!\t0.2098\t638491441988304896\tmichael jackson\tpositive\t#OnThisDay1987 CBS records shipped out the largest pre-order in the company\'s history for Michael Jackson\'s album Bad http://t.co/v4fkyOx2eW\r\n638528170455511040\t$\t0.3497\t638528170455511040\tmichael jackson\tpositive\tI just texted my friend that I\'d be busy all day tomorrow preparing to roast Michael Jackson tomorrow night.  Life is awesome.\r\n638576849354813440\t$\t0.3497\t638576849354813440\tmichael jackson\tpositive\tmom: "I say 23 because your birthday is on the 23rd" me: no you say it because mj  mom: michael jackson? me: did he play ball too? mom: oh.\r\n638594008437104640\t$ ...

# %%
#"MATCHES__STRING".split("__")
a="Apple,Orange,HoneyDrew"
x,y,z=a.split(',')
x,y,z
# Out:
# ('Apple', 'Orange', 'HoneyDrew')

# %%
tokenizedStr,types,confidence,originalStr = p.decode().split('\t')

# %%
tokenizedStr,types,confidence,originalStr
# Out:
# ('Google is not accounting for local culture in driving patterns .',
#  '^ V R N P A N P V N ,',
#  '0.9766 0.9953 0.9920 0.6011 0.9987 0.9830 0.9978 0.9947 0.5704 0.9873 0.9986',
#  'Google is not accounting for local culture in driving patterns.\r\n')

# %%
arr1 = tokenizedStr.split(' ')
arr2 = types.split(' ')
arr3 = confidence.split(' ')

# %%
arr3
# Out:
# ['0.9766',
#  '0.9953',
#  '0.9920',
#  '0.6011',
#  '0.9987',
#  '0.9830',
#  '0.9978',
#  '0.9947',
#  '0.5704',
#  '0.9873',
#  '0.9986']

# %%
#a = np.append([[1, 2, 3], [4, 5, 6]], [[7, 8, 9]], axis=0)
#for  i  in  range ( len(arr1) ): 
   #np.append([[arr1[i]], [arr2[i]],[arr3[i]]], axis=0)

# %%
# Creates a list containing 5 lists, each of 8 items, all set to 0
#w, h = 8, 5;
#Matrix = [[0 for x in range(w)] for y in range(h)] 
#Matrix

# %%
#a = np.matrix([arr1[0],arr2[0],arr3[0]])

#a = [[arr1[0],arr2[0],arr3[0]]];
#for  i in  range ( len(arr1) ): 
    #np.append(a,[[arr1[i], arr2[i],arr3[i]]],axis=0);
    #np.concatenate((a,[[arr1[i], arr2[i],arr3[i]]]),1);

#a
# Out:
# [['Google', '^', '0.9766']]

# %%
w = len(arr1);
h = 3;
a = [[0 for x in range(h)] for y in range(w)] 
for i in range (len(arr1)):
    a[i][0] = arr1[i];
    a[i][1] = arr2[i];
    a[i][2] = arr3[i];
    
print (a)
# Out:
# [['Google', '^', '0.9766'], ['is', 'V', '0.9953'], ['not', 'R', '0.9920'], ['accounting', 'N', '0.6011'], ['for', 'P', '0.9987'], ['local', 'A', '0.9830'], ['culture', 'N', '0.9978'], ['in', 'P', '0.9947'], ['driving', 'V', '0.5704'], ['patterns', 'N', '0.9873'], ['.', ',', '0.9986']]

# %%
w = len(arr1);
h = 3;
b = [[0 for x in range(h)] for y in range(w)]
